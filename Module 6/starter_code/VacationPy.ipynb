# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()

# !pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\rontr\anaconda3\lib\site-packages (0.15.0)
# Requirement already satisfied: numpy in c:\users\rontr\anaconda3\lib\site-packages (from folium) (1.25.1)
# Requirement already satisfied: requests in c:\users\rontr\anaconda3\lib\site-packages (from folium) (2.29.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\rontr\anaconda3\lib\site-packages (from folium) (0.7.0)
# Requirement already satisfied: jinja2>=2.9 in c:\users\rontr\anaconda3\lib\site-packages (from folium) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rontr\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rontr\anaconda3\lib\site-packages (from requests->folium) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rontr\anaconda3\lib\site-packages (from requests->folium) (1.26.15)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rontr\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rontr\anaconda3\lib\site-packages (from requests->folium) (3.4)

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# !pip install cartopy
# !pip install geoviews
# !pip install pyproj
# Out:
# Collecting cartopy
#   Downloading Cartopy-0.22.0-cp310-cp310-win_amd64.whl (11.2 MB)
#      ---------------------------------------- 11.2/11.2 MB 4.8 MB/s eta 0:00:00
# Collecting pyshp>=2.1
#   Downloading pyshp-2.3.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 46.5/46.5 kB 2.3 MB/s eta 0:00:00
# Collecting shapely>=1.7
#   Downloading shapely-2.0.2-cp310-cp310-win_amd64.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 46.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.4 in c:\users\rontr\anaconda3\lib\site-packages (from cartopy) (3.7.2)
# Collecting pyproj>=3.1.0
#   Downloading pyproj-3.6.1-cp310-cp310-win_amd64.whl (6.1 MB)
#      ---------------------------------------- 6.1/6.1 MB 29.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20 in c:\users\rontr\anaconda3\lib\site-packages (from cartopy) (23.0)
# Requirement already satisfied: numpy>=1.21 in c:\users\rontr\anaconda3\lib\site-packages (from cartopy) (1.25.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rontr\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (4.41.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rontr\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rontr\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (9.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rontr\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\rontr\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rontr\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rontr\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy) (0.11.0)
# Requirement already satisfied: certifi in c:\users\rontr\anaconda3\lib\site-packages (from pyproj>=3.1.0->cartopy) (2023.5.7)
# Requirement already satisfied: six>=1.5 in c:\users\rontr\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.4->cartopy) (1.16.0)
# Installing collected packages: shapely, pyshp, pyproj, cartopy
# Successfully installed cartopy-0.22.0 pyproj-3.6.1 pyshp-2.3.1 shapely-2.0.2
# Collecting geoviews
#   Downloading geoviews-1.11.0-py2.py3-none-any.whl (511 kB)
#      -------------------------------------- 511.2/511.2 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: param in c:\users\rontr\anaconda3\lib\site-packages (from geoviews) (2.0.1)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\rontr\anaconda3\lib\site-packages (from geoviews) (1.18.1)
# Requirement already satisfied: panel>=1.0.0 in c:\users\rontr\anaconda3\lib\site-packages (from geoviews) (1.3.1)
# Requirement already satisfied: shapely in c:\users\rontr\anaconda3\lib\site-packages (from geoviews) (2.0.2)
# Requirement already satisfied: packaging in c:\users\rontr\anaconda3\lib\site-packages (from geoviews) (23.0)
# Requirement already satisfied: pyproj in c:\users\rontr\anaconda3\lib\site-packages (from geoviews) (3.6.1)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\rontr\anaconda3\lib\site-packages (from geoviews) (0.22.0)
# Requirement already satisfied: numpy in c:\users\rontr\anaconda3\lib\site-packages (from geoviews) (1.25.1)
# Requirement already satisfied: bokeh<3.4.0,>=3.2.0 in c:\users\rontr\anaconda3\lib\site-packages (from geoviews) (3.3.1)
# Requirement already satisfied: xyzservices in c:\users\rontr\anaconda3\lib\site-packages (from geoviews) (2023.10.1)
# Requirement already satisfied: contourpy>=1 in c:\users\rontr\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (1.1.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\rontr\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (2.0.3)
# Requirement already satisfied: tornado>=5.1 in c:\users\rontr\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\rontr\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (9.4.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\rontr\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (3.1.2)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\rontr\anaconda3\lib\site-packages (from bokeh<3.4.0,>=3.2.0->geoviews) (6.0)
# Requirement already satisfied: pyshp>=2.1 in c:\users\rontr\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.3.1)
# Requirement already satisfied: matplotlib>=3.4 in c:\users\rontr\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.7.2)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\rontr\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.0)
# Requirement already satisfied: colorcet in c:\users\rontr\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\rontr\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.65.0)
# Requirement already satisfied: typing-extensions in c:\users\rontr\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.5.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\rontr\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (0.4.0)
# Requirement already satisfied: markdown-it-py in c:\users\rontr\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.0.0)
# Requirement already satisfied: bleach in c:\users\rontr\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.1.0)
# Requirement already satisfied: requests in c:\users\rontr\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.29.0)
# Requirement already satisfied: markdown in c:\users\rontr\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.5.1)
# Requirement already satisfied: linkify-it-py in c:\users\rontr\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.2)
# Requirement already satisfied: certifi in c:\users\rontr\anaconda3\lib\site-packages (from pyproj->geoviews) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rontr\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<3.4.0,>=3.2.0->geoviews) (2.1.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\rontr\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rontr\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (4.41.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rontr\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rontr\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\rontr\anaconda3\lib\site-packages (from matplotlib>=3.4->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rontr\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rontr\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.4.0,>=3.2.0->geoviews) (2023.3)
# Requirement already satisfied: colorama in c:\users\rontr\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\rontr\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\rontr\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\rontr\anaconda3\lib\site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.5.0)
# Requirement already satisfied: uc-micro-py in c:\users\rontr\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rontr\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rontr\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rontr\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\rontr\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (1.26.15)
# Installing collected packages: geoviews
# Successfully installed geoviews-1.11.0
# Requirement already satisfied: pyproj in c:\users\rontr\anaconda3\lib\site-packages (3.6.1)
# Requirement already satisfied: certifi in c:\users\rontr\anaconda3\lib\site-packages (from pyproj) (2023.5.7)

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 2,
    color = "City",
    alpha=0.5,
    hover_cols = ["City", "Humidity"]
)

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
filtered_cities_df = city_data_df[(city_data_df['Max Temp'] >= 20) & (city_data_df['Max Temp'] <= 25) & (city_data_df['Humidity'] < 70)&
    (city_data_df['Cloudiness'] <=50)]

# Drop any rows with null values
filtered_cities_df = filtered_cities_df.dropna()

# Display sample data
filtered_cities_df


# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = filtered_cities_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 0              faya      SA  18.3851   42.4509        35
# 9      saint-pierre      RE -21.3393   55.4781        68
# 53             lasa      IT  46.6166   10.7002        68
# 63            banda      IN  25.4833   80.3333        52
# 64           atuona      PF  -9.8000 -139.0333        69
# 106        palencia      ES  42.4167   -4.5000        30
# 152         kahului      US  20.8947 -156.4700        60
# 165        ambilobe      MG -13.2000   49.0500        62
# 189     grand gaube      MU -20.0064   57.6608        65
# 218    sao teotonio      PT  37.5128   -8.7071        60
# 229   san cristobal      VE   7.7669  -72.2250        45
# 237  cap malheureux      MU -19.9842   57.6142        65
# 239          rawson      AR -43.3002  -65.1023        25
# 240     tikaitnagar      IN  26.9500   81.5833        59
# 296            jalu      LY  29.0331   21.5482        37
# 298        valdivia      CL -39.8142  -73.2459        63
# 305         kingman      US  35.1894 -114.0530        49
# 328           viseu      PT  40.6610   -7.9097        39
# 340   santa rosalia      MX  27.3167 -112.2833        56
# 363          narwar      IN  25.6500   77.9000        55
# 381       roebourne      AU -20.7833  117.1333        65
# 391  saint-francois      FR  46.4154    3.9054        57
# 421          stolac      BA  43.0844   17.9575        68
# 430         pachino      IT  36.7186   15.0907        67
# 516  guerrero negro      MX  27.9769 -114.0611        68

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = filtered_cities_df[['City', 'Country', 'Lat', 'Lng', 'Humidity']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ""

# Display sample data
hotel_df
# Out:
#                City Country      Lat       Lng  Humidity Hotel Name
# 0              faya      SA  18.3851   42.4509        35
# 9      saint-pierre      RE -21.3393   55.4781        68
# 53             lasa      IT  46.6166   10.7002        68
# 63            banda      IN  25.4833   80.3333        52
# 64           atuona      PF  -9.8000 -139.0333        69
# 106        palencia      ES  42.4167   -4.5000        30
# 152         kahului      US  20.8947 -156.4700        60
# 165        ambilobe      MG -13.2000   49.0500        62
# 189     grand gaube      MU -20.0064   57.6608        65
# 218    sao teotonio      PT  37.5128   -8.7071        60
# 229   san cristobal      VE   7.7669  -72.2250        45
# 237  cap malheureux      MU -19.9842   57.6142        65
# 239          rawson      AR -43.3002  -65.1023        25
# 240     tikaitnagar      IN  26.9500   81.5833        59
# 296            jalu      LY  29.0331   21.5482        37
# 298        valdivia      CL -39.8142  -73.2459        63
# 305         kingman      US  35.1894 -114.0530        49
# 328           viseu      PT  40.6610   -7.9097        39
# 340   santa rosalia      MX  27.3167 -112.2833        56
# 363          narwar      IN  25.6500   77.9000        55
# 381       roebourne      AU -20.7833  117.1333        65
# 391  saint-francois      FR  46.4154    3.9054        57
# 421          stolac      BA  43.0844   17.9575        68
# 430         pachino      IT  36.7186   15.0907        67
# 516  guerrero negro      MX  27.9769 -114.0611        68

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "types":"lodging",
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude, longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = response.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df.head()
# Out:
# Starting hotel search
# faya - nearest hotel: No hotel found
# saint-pierre - nearest hotel: Tropic Hotel
# lasa - nearest hotel: Hotel "Drei Kreuz"
# banda - nearest hotel: #acnindiafy21
# atuona - nearest hotel: Pearl Resort
# palencia - nearest hotel: Hotel Área de Servicio Los Chopos
# kahului - nearest hotel: Maui Seaside Hotel
# ambilobe - nearest hotel: Hôtel National
# grand gaube - nearest hotel: Hotel Lux- Grand Gaube
# sao teotonio - nearest hotel: Case da Lupa
# san cristobal - nearest hotel: Terra Sur
# cap malheureux - nearest hotel: Cape Garden
# rawson - nearest hotel: Hotel Deportivo
# tikaitnagar - nearest hotel: No hotel found
# jalu - nearest hotel: فندق جالو السياحي
# valdivia - nearest hotel: Esmeralda
# kingman - nearest hotel: Home2 Suites by Hilton Kingman
# viseu - nearest hotel: No hotel found
# santa rosalia - nearest hotel: Sol y Mar
# narwar - nearest hotel: No hotel found
# roebourne - nearest hotel: No hotel found
# saint-francois - nearest hotel: Chez Lily
# stolac - nearest hotel: Bregava
# pachino - nearest hotel: Hotel Celeste
# guerrero negro - nearest hotel: Plaza sal paraiso
#             City Country      Lat       Lng  Humidity          Hotel Name
# 0           faya      SA  18.3851   42.4509        35      No hotel found
# 9   saint-pierre      RE -21.3393   55.4781        68        Tropic Hotel
# 53          lasa      IT  46.6166   10.7002        68  Hotel "Drei Kreuz"
# 63         banda      IN  25.4833   80.3333        52       #acnindiafy21
# 64        atuona      PF  -9.8000 -139.0333        69        Pearl Resort

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

import hvplot.pandas

# Assuming hotel_df is your DataFrame with hotel information

# Create a scatter plot using hvplot.points
scatter_plot = hotel_df.hvplot.points(
    x='Lng',
    y='Lat',
    size='Humidity',
    color = "Hotel Name",
    alpha=0.5,
    hover_cols=["Hotel Name","City","Country"],
    geo=True,  
    tiles='OSM',
    frame_height=400,
)

# Display the plot
scatter_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (Hotel Name,Humidity,City,Country)
